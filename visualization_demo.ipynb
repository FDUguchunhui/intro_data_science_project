# %%
import pubtools.visualization as visua

# %% [markdown]
# #### Show the publication number by month

# %%
visua.paper_by_month("HIV.csv")
# Out:
# month
# 2020-01    707
# 2020-02    719
# 2020-03    689
# 2020-04    740
# 2020-05    676
# 2020-06    693
# 2020-07    786
# 2020-08    783
# Freq: M, Name: month, dtype: int64

# %% [markdown]
# #### Generate the summary statistics

# %%
visua.summary("HIV.csv")
# Out:
# {'mean': 724.125,
#  'std': 39.34602108218822,
#  'range': (676, 786),
#  'quantiles': array([692.  , 713.  , 750.75])}

# %% [markdown]
# #### Generate the plot showing the trend of publication number

# %%
visua.plot_poisson("HIV.csv")
# Out:
# (<ggplot: (-9223363249716036941)>,
#  {'whiskers': [<matplotlib.lines.Line2D at 0x7fdea47ab0f0>,
# ...
#   'caps': [<matplotlib.lines.Line2D at 0x7fdea47ab7b8>,
# ...
#   'boxes': [<matplotlib.lines.Line2D at 0x7fdea47a0f60>],
#   'medians': [<matplotlib.lines.Line2D at 0x7fdea47abe48>],
#   'fliers': [<matplotlib.lines.Line2D at 0x7fde9dd641d0>],
#   'means': []})
